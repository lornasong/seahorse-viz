# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import griddata
# %matplotlib inline

# %%
dive = pd.read_csv("/Users/lornasong/pydir/sh-data-format/dive_data.csv",
                   index_col = None,  header = 0,  low_memory = False,  na_values = '')

# %%
x=np.linspace(-3,3,40)
y=np.linspace(-3,3,40)

x, y= np.meshgrid(x,y)
z=x+y
plt.contour(x,y,z)
#print x
#print y
#print z
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x10e368bd8>

# %%
#plt.contour(dive['LONGITUDE'], dive['LATITUDE'], dive['DEPTH'])
df = pd.DataFrame()
df['a'] = dive['SITE']
df['x'] = dive['LATITUDE']
df['y'] = dive['LONGITUDE']
df['z'] = dive['DEPTH']
df = df.drop_duplicates(['a'])
#df.pivot(index = 'y', columns = 'x', values = 'z')
#z = pd.pivot_table(df, values = 'z', index = 'y', cols = 'x')
#andas.pivot_table(df,values='count',index='site_id',cols='week')

#x = z.columns.values.tolist()
#y = z.index.values.tolist()
print len(df['x'])
print len(df['y'])
#z = z.as_matrix()
#z.to_csv("/Users/lornasong/test.csv")
x2, y2 = np.meshgrid(x, y)

xi = np.linspace(min(x), max(x), 586)
yi = np.linspace(min(y), max(y), 586)
z = df['z'].as_matrix()
len(z)
# Out:
# 122
# 122
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-80d40dd39889> in <module>()
#      18 x2, y2 = np.meshgrid(x, y)
#      19
# ---> 20 xi = np.linspace(min(x), max(x), 586)
#      21 yi = np.linspace(min(y), max(y), 586)
#      22 z = df['z'].as_matrix()
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
df = pd.DataFrame()
df['a'] = dive['SITE']
df['x'] = dive['LATITUDE']
df['y'] = dive['LONGITUDE']
df['z'] = dive['DEPTH']
df = df.drop_duplicates(['a'])

x = df['x']
y = df['y']
z = df['z'].as_matrix()
print len(x)
print len(y)
print len(z)
xi = np.linspace(min(x), max(x), 122)
yi = np.linspace(min(y), max(y), 122)
#zi = griddata(xi, yi, zi)
#zi = griddata((x, y), z, (xi[None,:], yi[:,None]), method='cubic')
#zi = pd.pivot_table(df, values = 'z', index = 'y', columns = 'x')
#zi = zi.as_matrix()
zi
# Out:
# 122
# 122
# 122
# x           10.626700  10.627406  10.628069  10.628272  10.628369  10.628419  \
# y
# 103.304061        NaN        NaN        NaN        NaN        NaN        NaN
# 103.304722        NaN        NaN        NaN        NaN        NaN        NaN
# 103.305700        NaN        NaN        NaN        NaN        NaN        NaN
# 103.306289        NaN        NaN        NaN        NaN        NaN        NaN
# 103.306364        NaN        NaN        NaN        NaN        NaN        NaN
# 103.306378        NaN        NaN        NaN        NaN        NaN        NaN
# 103.306622        NaN        NaN        NaN        NaN        NaN        NaN
# 103.306708        NaN        NaN        NaN        NaN        NaN        NaN
# 103.306772        NaN        NaN        NaN        NaN        NaN        NaN
# 103.306936        NaN        NaN        NaN        NaN        NaN        NaN
# 103.306956        NaN        NaN        NaN        NaN        NaN        NaN
# 103.307042        NaN        NaN        NaN        NaN        NaN        NaN
# 103.307108        NaN        NaN        NaN        NaN        NaN        NaN
# 103.307375        NaN        NaN        NaN        NaN        NaN        NaN
# 103.307436        NaN        NaN        NaN        NaN        NaN        NaN
# 103.307500        NaN        NaN        NaN        NaN        NaN        NaN
# 103.307522        NaN        NaN        NaN        NaN        NaN        NaN
# 103.307689        NaN        NaN        NaN        NaN        NaN        NaN
# 103.307789        NaN        NaN        NaN        NaN        NaN        NaN
# 103.308003        NaN        NaN        NaN        NaN        NaN        NaN
# 103.308031        NaN        NaN        NaN        NaN        NaN        NaN
# 103.308036        NaN        NaN        NaN        NaN        NaN        NaN
# 103.308161        NaN        NaN        NaN        NaN        NaN        NaN
# 103.308183        NaN        NaN        NaN        NaN        NaN        NaN
# 103.308250        NaN        NaN        NaN        NaN        NaN        NaN
# 103.308672        NaN        NaN        NaN        NaN        NaN        NaN
# 103.308992        NaN        NaN        NaN        NaN        NaN        NaN
# 103.309111        NaN        NaN        NaN        NaN        NaN        NaN
# 103.309322        NaN        NaN        NaN        NaN        NaN        NaN
# 103.309436        NaN        NaN        NaN        NaN        NaN        NaN
# ...               ...        ...        ...        ...        ...        ...
# 103.315086        NaN        NaN        NaN        NaN        NaN        NaN
# 103.315439        NaN        NaN        NaN        NaN        NaN        NaN
# 103.315478        NaN        NaN        NaN        NaN        NaN        NaN
# 103.315531        NaN        NaN        NaN        NaN        NaN        NaN
# 103.315636        NaN        NaN        NaN        NaN        NaN        NaN
# 103.315653        NaN        NaN        NaN        NaN        NaN        NaN
# 103.315761        NaN        NaN        NaN        NaN        NaN        NaN
# 103.315792        NaN        NaN        NaN        NaN        NaN        NaN
# 103.316283        NaN        NaN        NaN        NaN        NaN        NaN
# 103.316322        NaN        NaN        NaN        NaN        NaN        NaN
# 103.316397        NaN        NaN         12        NaN        NaN        NaN
# 103.316603        NaN        NaN        NaN        NaN        NaN        NaN
# 103.316736        NaN        NaN        NaN        NaN        NaN        NaN
# 103.316819        NaN        NaN        NaN       16.5        NaN        NaN
# 103.316847        NaN        NaN        NaN        NaN        NaN        NaN
# 103.317117        NaN        NaN        NaN        NaN        NaN        NaN
# 103.317383        NaN        NaN        NaN        NaN        NaN        NaN
# 103.317444        NaN        NaN        NaN        NaN        NaN        NaN
# 103.317525        NaN        NaN        NaN        NaN        NaN        NaN
# 103.317589        NaN        NaN        NaN        NaN        NaN        NaN
# 103.317650        NaN        NaN        NaN        NaN        NaN        NaN
# 103.317703        NaN        NaN        NaN        NaN        NaN        NaN
# 103.317708        NaN        NaN        NaN        NaN        NaN        NaN
# 103.317847        NaN        NaN        NaN        NaN        NaN        NaN
# 103.318225        NaN        NaN        NaN        NaN        NaN        NaN
# 103.318294        NaN        NaN        NaN        NaN        NaN        NaN
# 103.318486        NaN        NaN        NaN        NaN        NaN        NaN
# 103.318542        NaN        NaN        NaN        NaN        NaN        NaN
# 103.319003        NaN        NaN        NaN        NaN        NaN        NaN
# 103.320108        NaN        NaN        NaN        NaN        NaN        NaN
#
# x           10.628469  10.629081  10.629381  10.629636    ...      10.642511  \
# y                                                         ...
# 103.304061        NaN        NaN        NaN        NaN    ...            NaN
# 103.304722        NaN        NaN        NaN        NaN    ...            NaN
# 103.305700        NaN        NaN        NaN        NaN    ...            NaN
# 103.306289        NaN        NaN        NaN        NaN    ...            NaN
# 103.306364        NaN        NaN        NaN        NaN    ...            NaN
# 103.306378        NaN        NaN        NaN        NaN    ...            NaN
# 103.306622        NaN        NaN        NaN        NaN    ...            NaN
# 103.306708        NaN        NaN        NaN        NaN    ...            NaN
# 103.306772        NaN        NaN        NaN        NaN    ...            NaN
# 103.306936        NaN        NaN        NaN        NaN    ...            NaN
# 103.306956        NaN        NaN        NaN        NaN    ...            NaN
# 103.307042        NaN        NaN        NaN        NaN    ...            NaN
# 103.307108        NaN        NaN        NaN        NaN    ...            NaN
# 103.307375        NaN        NaN        NaN        NaN    ...            NaN
# 103.307436        NaN        NaN        NaN        NaN    ...            NaN
# 103.307500        NaN        NaN        NaN        NaN    ...            NaN
# 103.307522        NaN        NaN        NaN        NaN    ...            NaN
# 103.307689        NaN        NaN        NaN        NaN    ...            NaN
# 103.307789        NaN        NaN        NaN        NaN    ...            NaN
# 103.308003        NaN        NaN        NaN        NaN    ...            NaN
# 103.308031        NaN        NaN        NaN        NaN    ...            NaN
# 103.308036        NaN        NaN        NaN        NaN    ...            NaN
# 103.308161        NaN        NaN        NaN        NaN    ...            NaN
# 103.308183        NaN        NaN        NaN        NaN    ...            NaN
# 103.308250        NaN        NaN        NaN        NaN    ...            NaN
# 103.308672        NaN        NaN        NaN        NaN    ...            NaN
# 103.308992        NaN        NaN        6.3        NaN    ...            NaN
# 103.309111        NaN        NaN        NaN        NaN    ...            NaN
# 103.309322        NaN        NaN        NaN        NaN    ...            NaN
# 103.309436        NaN        NaN        NaN        NaN    ...            NaN
# ...               ...        ...        ...        ...    ...            ...
# 103.315086        NaN        NaN        NaN        NaN    ...            NaN
# 103.315439        NaN        NaN        NaN        NaN    ...            NaN
# 103.315478        NaN        NaN        NaN        NaN    ...            NaN
# 103.315531        NaN        NaN        NaN        NaN    ...           22.6
# 103.315636        NaN        NaN        NaN        NaN    ...            NaN
# 103.315653        NaN        NaN        NaN        NaN    ...            NaN
# 103.315761        NaN        NaN        NaN        NaN    ...            NaN
# 103.315792        NaN        NaN        NaN        NaN    ...            NaN
# 103.316283        NaN        NaN        NaN        NaN    ...            NaN
# 103.316322        NaN        NaN        NaN        NaN    ...            NaN
# 103.316397        NaN        NaN        NaN        NaN    ...            NaN
# 103.316603        NaN        NaN        NaN        NaN    ...            NaN
# 103.305700        NaN        NaN        NaN
# 103.306289        NaN        NaN        NaN
# 103.306364        NaN        NaN        NaN
# 103.306378        NaN        NaN        NaN
# 103.306622        NaN        NaN        NaN
# 103.306708        NaN        NaN        NaN
# 103.306772        NaN        NaN        NaN
# 103.306936        NaN        NaN        NaN
# 103.306956        NaN        NaN        NaN
# 103.307042        NaN        NaN        NaN
# 103.307108        NaN        NaN        NaN
# 103.307375        NaN        NaN        NaN
# 103.307436        NaN        NaN        NaN
# 103.307500        NaN        NaN        NaN
# 103.307522        NaN        NaN        NaN
# 103.307689        NaN        NaN        NaN
# 103.307789        NaN        NaN        NaN
# 103.308003        NaN        NaN        NaN
# 103.308031        NaN        NaN        NaN
# 103.308036        NaN        NaN        NaN
# 103.308161        NaN        NaN        NaN
# 103.308183        NaN        NaN        NaN
# 103.308250        NaN        NaN        NaN
# 103.308672        NaN        NaN        NaN
# 103.308992        NaN        NaN        NaN
# 103.309111        NaN        NaN        NaN
# 103.309322        NaN        NaN        NaN
# 103.309436        NaN        NaN        NaN
# ...               ...        ...        ...
# 103.315086        NaN        NaN        NaN
# 103.315439        NaN        NaN        NaN
# 103.315478        NaN        NaN         22
# 103.315531        NaN        NaN        NaN
# 103.315636        NaN        NaN        NaN
# 103.315653        NaN        NaN        NaN
# 103.315761        NaN        NaN        NaN
# 103.315792        NaN       26.3        NaN
# 103.316283        NaN        NaN        NaN
# 103.316322        NaN        NaN        NaN
# 103.316397        NaN        NaN        NaN
# 103.316603        NaN        NaN        NaN
# 103.316736        NaN        NaN        NaN
# 103.316819        NaN        NaN        NaN
# 103.316847        NaN        NaN        NaN
# 103.317117        NaN        NaN        NaN
# 103.317383        NaN        NaN        NaN
# 103.317444        NaN        NaN        NaN
# 103.317525        NaN        NaN        NaN
# 103.317589        NaN        NaN        NaN
# 103.317650        NaN        NaN        NaN
# 103.317703        NaN        NaN        NaN
# 103.317708        NaN        NaN        NaN
# 103.317847        NaN        NaN        NaN
# 103.318225        NaN        NaN        NaN
# 103.318294        NaN        NaN        NaN
# 103.318486        NaN        NaN        NaN
# 103.318542        NaN        NaN        NaN
# 103.319003        NaN        NaN        NaN
# 103.320108        NaN        NaN        NaN
#
# [117 rows x 119 columns]

# %%
plt.contour(xi,yi,zi,15,linewidths=0.5,colors='k')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-f8c1d5682aeb> in <module>()
# ----> 1 plt.contour(xi,yi,zi,15,linewidths=0.5,colors='k')
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/pyplot.pyc in contour(*args, **kwargs)
#    2630         ax.hold(hold)
#    2631     try:
# -> 2632         ret = ax.contour(*args, **kwargs)
#    2633         draw_if_interactive()
#    2634     finally:
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/axes.pyc in contour(self, *args, **kwargs)
#    7974             self.cla()
#    7975         kwargs['filled'] = False
# -> 7976         return mcontour.QuadContourSet(self, *args, **kwargs)
#    7977     contour.__doc__ = mcontour.QuadContourSet.contour_doc
#    7978
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/contour.pyc in __init__(self, ax, *args, **kwargs)
#    1412         are described in QuadContourSet.contour_doc.
#    1413         """
# -> 1414         ContourSet.__init__(self, ax, *args, **kwargs)
#    1415
#    1416     def _process_args(self, *args, **kwargs):
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/contour.pyc in __init__(self, ax, *args, **kwargs)
#     858         self._transform = kwargs.get('transform', None)
#     859
# --> 860         self._process_args(*args, **kwargs)
#     861         self._process_levels()
#     862
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/contour.pyc in _process_args(self, *args, **kwargs)
#    1425             self.zmax = args[0].zmax
#    1426         else:
# -> 1427             x, y, z = self._contour_args(args, kwargs)
#    1428
#    1429             _mask = ma.getmask(z)
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/contour.pyc in _contour_args(self, args, kwargs)
#    1489             args = args[1:]
#    1490         elif Nargs <= 4:
# -> 1491             x, y, z = self._check_xyz(args[:3], kwargs)
#    1492             args = args[3:]
#    1493         else:
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/contour.pyc in _check_xyz(self, args, kwargs)
#    1536
#    1537             if nx != Nx:
# -> 1538                 raise TypeError("Length of x must be number of columns in z.")
#    1539
#    1540             if ny != Ny:
#
# TypeError: Length of x must be number of columns in z.

# %%
from scipy.interpolate import griddata
xi = np.linspace(min(x), max(x), 556)
yi = np.linspace(min(y), max(y), 545)
zi = griddata((y, x), z, (yi[None,:], xi[:,None]), method='cubic')
print len(x)
print len(y)
print len(xi)
print len(yi)
print z
#contour(xi, yi, zi)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-143-2e80dd1f800c> in <module>()
#       2 xi = np.linspace(min(x), max(x), 556)
#       3 yi = np.linspace(min(y), max(y), 545)
# ----> 4 zi = griddata((y, x), z, (yi[None,:], xi[:,None]), method='cubic')
#       5 print len(x)
#       6 print len(y)
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/interpolate/ndgriddata.pyc in griddata(points, values, xi, method, fill_value)
#     162     """
#     163
# --> 164     points = _ndim_coords_from_arrays(points)
#     165
#     166     if points.ndim < 2:
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/interpolate/interpnd.so in scipy.interpolate.interpnd._ndim_coords_from_arrays (scipy/interpolate/interpnd.c:3444)()
#
# /Library/Python/2.7/site-packages/numpy-1.9.1-py2.7-macosx-10.10-intel.egg/numpy/lib/stride_tricks.pyc in broadcast_arrays(*args)
#      99             # There must be at least two non-1 lengths for this axis.
#     100             raise ValueError("shape mismatch: two or more arrays have "
# --> 101                 "incompatible dimensions on axis %r." % (axis,))
#     102         elif len(unique) == 2:
#     103             # There is exactly one non-1 length. The common shape will take
#
# ValueError: shape mismatch: two or more arrays have incompatible dimensions on axis 0.

# %%
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
import numpy.ma as ma
import numpy as np
from numpy.random import uniform, seed
# make up some randomly distributed data
seed(1234)
npts = 200
x = uniform(-2,2,npts)
y = uniform(-2,2,npts)
z = x*np.exp(-x**2-y**2)
# define grid.
xi = np.linspace(-2.1,2.1,100)
yi = np.linspace(-2.1,2.1,100)

# %%
# grid the data.
zi = griddata((x, y), z, (xi[None,:], yi[:,None]), method='cubic')
#zi = griddata(xi, yi, zi)

# %%
# contour the gridded data, plotting dots at the randomly spaced data points.
CS =plt.contour(xi,yi,zi,15,linewidths=0.5,colors='k')
#CS = plt.contourf(xi,yi,zi,15,cmap=plt.cm.jet)
#plt.colorbar() # draw colorbar
# plot data points.
#plt.scatter(x,y,marker='o',c='b',s=5)
#plt.xlim(-2,2)
#plt.ylim(-2,2)
#plt.title('griddata test (%d points)' % npts)
plt.show()

# %%
len(zi)
# Out:
# 100
